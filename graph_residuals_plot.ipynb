# %%
import random
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('output.csv')
vx = np.linspace(0, 26)
vy = 0 * vx
m = 527.60012028
iteration = 0
for x in data['Meetings Attended']:
    plt.scatter(x, data.loc[iteration, 'Grade Increase'] - ((x * m) -2589.1353592516152), c='#ff6c3b')
    iteration += 1
plt.plot(vx, vy, c='r')
plt.show()
